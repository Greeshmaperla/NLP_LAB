# %% [markdown]
# <a href="https://colab.research.google.com/github/Greeshmaperla/NLP_LAB/blob/main/spell_correction_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from textblob import TextBlob

# Original sentence with spelling mistakes
text = "I havv goood speling."

# Create a TextBlob object
blob = TextBlob(text)

# Correct the spelling mistakes
corrected_text = blob.correct()

# Print the corrected sentence
print(corrected_text)
# Out:
# I have good spelling.
