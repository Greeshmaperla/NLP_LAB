# %% [markdown]
# <a href="https://colab.research.google.com/github/Greeshmaperla/NLP_LAB/blob/main/ngram_smoothing_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from collections import Counter

text = "I love NLP and I love Python."
tokens = text.lower().split()

counts = Counter(tokens)
vocab = set(tokens)
V = len(vocab)
total = sum(counts.values())

# Apply Laplace smoothing
smoothed_probs = {word: (counts[word] + 1) / (total + V) for word in vocab}

print("Smoothed unigram probabilities:")
for word, prob in smoothed_probs.items():
    print(f"{word}: {prob:.4f}")
# Out:
# Smoothed unigram probabilities:
# i: 0.2500
# love: 0.2500
# nlp: 0.1667
# python.: 0.1667
# and: 0.1667
