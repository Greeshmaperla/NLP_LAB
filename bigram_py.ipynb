# %% [markdown]
# <a href="https://colab.research.google.com/github/Greeshmaperla/NLP_LAB/blob/main/bigram_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
text = "I love NLP and I love Python."
tokens = text.lower().split()
bigrams = [(tokens[i], tokens[i+1]) for i in range(len(tokens)-1)]
print(bigrams)
# Out:
# [('i', 'love'), ('love', 'nlp'), ('nlp', 'and'), ('and', 'i'), ('i', 'love'), ('love', 'python.')]
